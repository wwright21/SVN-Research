# %%
import gmaps
import pandas as pd
from api_keys import g_key

# %%
gmaps.configure(api_key=g_key)

# %%
df1 = pd.read_csv('Pediatrics_Geocoded.csv')
df1
# Out:
#        Unnamed: 0                      Address            City State ZipCode  \
# 0           18317  2014 WEST CROSS CREEK DRIVE           Nampa    GA   83686
# 1            5728              64640 300TH ST.          GIBBON    GA   55335
# 2             285           9104 WELLINGTON DR      LITTLE ELM    GA   75068
# 3           10077           9104 WELLINGTON DR      LITTLE ELM    GA   75068
# 4           18871           9104 WELLINGTON DR      Little Elm    GA   75068
# ...           ...                          ...             ...   ...     ...
# 19459       18044      4736 LANDING WATER PATH          BUFORD    GA   30519
# 19460       18253              269 SHERWOOD DR    Clarkesville    GA   30523
# 19461       18391       6850 SCARLETTE OAK WAY  Flowery Branch    GA   30542
# 19462       18651             3302 ED DODD TRL     Gainesville    GA   30506
# 19463       19401         2361 LEGACY MAPLE DR       Braselton    GA   30517
#
#              Lat       Long
# 0      36.956571 -98.678313
# 1      44.515083 -94.539373
# 2      32.678125 -88.864506
# 3      32.678125 -88.864506
# 4      32.678125 -88.864506
# ...          ...        ...
# 19459  34.132132 -83.956813
# 19460  34.618459 -83.515529
# 19461  34.156626 -83.912266
# 19462  34.360250 -83.857118
# 19463  34.108178 -83.831372
#
# [19464 rows x 7 columns]

# %%
locations = df1[['Lat','Long']].astype(float)

gmaps.configure(api_key=g_key)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, dissipating=False, max_intensity=25,
                                 point_radius = 0.01, opacity=0.5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
